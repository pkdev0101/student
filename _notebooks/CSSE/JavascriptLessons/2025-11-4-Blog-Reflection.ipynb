# %%
---
layout: post
toc: true
title: CSSE Final Blog - Pranay Kamath
description: Retrospective blog reflecting on Sprint 2 and my experience learning JavaScript fundamentals for game development
permalink: /csse/blogs
author: Pranay Kamath
---

# %%
### Final Blog

# %% [markdown]
# ### Sprint 1 – Onboarding Challenge
# ---
#
# ## Task Overview
# Sprint 1 was about setting up my personal development environment and learning how to manage code and workflows as a Learning Experience Designer. The main focus was on **VSCode**, **GitHub**, **Make**, and Linux commands to get my GitHub Pages site running.
#
# ## What I Actually Did
# I started by creating my a personal workspace:
# - Used `mkdir -p <USERNAME>` to create a personal directory.
# - Cloned the student repository using `git clone https://github.com/<USERNAME>/student.git`.
# - Ran `./scripts/activate.sh` to configure GitHub credentials.
# - Set up and activated a Python virtual environment with `./scripts/venv.sh` and `venv`.
#
# Next, I installed all dependencies:
# ```bash
# pip install -r requirements.txt
# gem install faraday-retry
# ```
# I had to debug multiple issues along the way, such as missing packages and misconfigured environment variables. Running Make commands like `make serve-minema` allowed me to serve the site locally and test changes before pushing.
#
# I also practiced committing and pushing code to GitHub:
# ```bash
# git add .
# git commit -m "Setup initial project"
# git push origin main
# ```
# Watching GitHub Actions trigger automatically and seeing my changes live on GitHub Pages was a key part of the experience.
#
# ## Challenges I Faced
# - Make commands sometimes failed due to missing dependencies.
# - Activating virtual environments in Kasm/Linux required troubleshooting.
# - Ensuring the GitHub Pages site published correctly after multiple commits.
#
# ## What I Learned
# - How to create directories and organize projects using Linux commands.
# - How to clone and manage GitHub repositories effectively.
# - How to run and debug Make commands for automation.
# - How to configure and activate Python virtual environments.
# - How GitHub Actions work to deploy GitHub Pages automatically.
# - How to systematically troubleshoot errors and document solutions.
#
# ## My Favorite Part
# Getting my site online and fully functional was very nice to see. Every bug I fixed and command I ran made me feel more confident in managing my own development environment.
#
# ## Overall Reflection
#
# Sprint 1 taught me that a big part of coding is understanding the setup and tools. Running commands, troubleshooting, and managing repositories were all valuable skills I can build on. Sprint 1 set me up to keep improving my workflow and start working on more complex projects with my personal GitHub Pages setup fully established.

# %%
## What I Learned

Sprint 2 was all about diving deeper into **JavaScript** and applying it to small coding exercises and games. I focused on building a strong foundation in programming concepts while connecting them to interactive web projects. Here’s a breakdown of what I practiced:

- **Variables and Data Types** – I worked with `let` and `const` to store numbers, strings, and booleans. Understanding the differences between these helped me manage data more effectively in my programs.  
- **Operators and Expressions** – I used mathematical operators to perform calculations and logical operators to create conditions for decision-making in code.  
- **Conditionals** – `if`, `else if`, and `else` statements became tools to control program flow and handle multiple scenarios, like checking player scores or determining game outcomes.  
- **Loops** – I practiced `for` and `while` loops to iterate through arrays and perform repeated actions, which was useful for tasks like updating a scoreboard or managing multiple game objects.  
- **Functions** – Writing reusable functions allowed me to break problems into smaller, manageable pieces, like calculating totals, updating stats, or running repeated animations.  
- **Objects and JSON** – I created objects to group related data and practiced using JSON-style structures. This was especially helpful when managing properties of game objects like players, enemies, and items.  
- **DOM Manipulation** – I used `document.getElementById` and `document.querySelector` to interact with HTML elements, allowing me to display dynamic content, take user input, and update the game interface in real-time.  
- **Simple Game Logic** – Applying these concepts together, I experimented with small game mechanics, like moving objects, tracking scores, and responding to user actions.

### Challenges and Growth

- Debugging was a big part of the process—figuring out why loops didn’t behave as expected or why functions returned unexpected results taught me patience and problem-solving skills.  
- Integrating JavaScript with HTML was initially tricky, but it helped me understand how web pages respond to user actions.  
- Managing multiple objects and their properties improved my organizational skills and reinforced how OOP concepts can be applied even in small projects.  
- Collaborating with peers on exercises encouraged me to explain my code clearly and learn from others’ approaches.

### Reflection

This sprint was a major step forward in my coding journey. By practicing **variables, loops, functions, objects, and DOM manipulation**, I gained confidence in writing interactive programs. The hands-on homework and small game projects taught me not just syntax, but how to **think like a programmer**: breaking problems down, testing solutions, and iterating until the code works. These skills will be the foundation for more advanced web development and game programming in upcoming sprints.
