# %% [markdown]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: CSSE Classes and Methods HW
# description: These are the homework problems and popcorn hacks.
# permalink: /csse/fall_2025/javascript/classes-and-methods/homework
# author: Adya S, Niharika B, Salma Z, Anika S, Sophie H
# ---

# %% [markdown]
# ## **Classes and Methods**

# %% [markdown]
# ### <u>Popcorn Hack 1 - Dice Roller</u>
#
#
# Instructions:
# Finish the code in the cell below (fill in underlines and add lines of code) so it works as described:
#
# - Create a class called Dice that:
#     - Has a property for the number of sides.
#     - Has a method roll() that returns a random number between 1 and the number of sides.
#
#
# At the bottom, test your game by making a DiceGame object and calling roll() a few times.
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
# %%javascript
#
# // Create a Dice class
# class Dice {
#   constructor(sides) {
#     this.sides = sides; // property for number of sides
#   }
#
#   // roll() method returns a random integer from 1 to sides
#   roll() {
#     return Math.floor(Math.random() * this.sides) + 1;
#   }
# }
#
# // Instantiate a Dice object
# let myDice = new Dice(6);
#
# // Test the roll method a few times
# console.log("🎲 Popcorn Hack 1 - Dice Roller 🎲");
#
# // Roll 3 times and log each result
# for (let i = 1; i <= 3; i++) {
#   let result = myDice.roll();
#   console.log(`Roll ${i}: ${result}`);
# }

# %% [markdown]
# ### <u>Popcorn Hack 2 - Pet Simulator</u>
#
#
# This hack is a bit more complicated than the first. Points will be awarded based on effort and completion.
#
#
# Analyze the block of code below. Then, complete the following instructions:
#
#
# 1) Create a simple Pet class by filling in the _________.
#
# 2) Add at least 2 properties (like hunger, energy, or happiness). EX: Stats decrease over time.
#
# 3) Add at least two functioning methods (such as feed, play, or sleep) EX: Buttons increase stats.
#
# 4) Give your pet a name and print their current properties.
#
# 5) Bonus: Add a "status" method to print all your pet's stats.
#
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
# %%javascript
# // Create or reuse a container element to display the pet UI
# (function() {
#   let element = document.getElementById('petDisplay');
#   if (!element) {
#     element = document.createElement('div');
#     element.id = 'petDisplay';
#     // add minimal styling so it's visible in the notebook
#     element.style.border = '1px solid #ddd';
#     element.style.padding = '12px';
#     element.style.margin = '8px 0';
#     element.style.maxWidth = '500px';
#     document.body.appendChild(element);
#   }
#
#   // Pet class
#   class Pet {
#     constructor(name) {
#       this.name = name;
#       // starting stats (you can tweak these)
#       this.hunger = 1;      // almost full
#       this.energy = 8;      // energetic
#       this.happiness = 10;  // very happy
#     }
#
#     feed() {
#       this.hunger = Math.max(0, this.hunger - 2);
#       this.energy = Math.min(10, this.energy + 1);
#       this.happiness = Math.min(10, this.happiness + 1);
#       this.status(`${this.name} just enjoyed a big snack! 🍗`);
#     }
#
#     play() {
#       this.energy = Math.max(0, this.energy - 2);
#       this.hunger = Math.min(10, this.hunger + 1);
#       this.happiness = Math.min(10, this.happiness + 1);
#       this.status(`${this.name} had a blast playing! 🎉`);
#     }
#
#     sleep() {
#       this.energy = Math.min(10, this.energy + 3);
#       this.hunger = Math.min(10, this.hunger + 1);
#       this.status(`${this.name} took a cozy nap. 😴`);
#     }
#
#     // update the DOM display and reattach button handlers
#     status(message) {
#       element.innerHTML = `
#         <h3>${message}</h3>
#         <p><strong>${this.name}'s Current Stats</strong></p>
#         <ul>
#           <li>Hunger: ${this.hunger}</li>
#           <li>Energy: ${this.energy}</li>
#           <li>Happiness: ${this.happiness}</li>
#         </ul>
#         <div style="margin-top:8px;">
#           <button id="feedBtn">Feed</button>
#           <button id="playBtn">Play</button>
#           <button id="sleepBtn">Sleep</button>
#           <button id="logBtn" style="margin-left:8px;">Log → Console</button>
#         </div>
#       `;
#
#       // attach handlers (use arrow functions to keep `this`)
#       document.getElementById('feedBtn').onclick = () => this.feed();
#       document.getElementById('playBtn').onclick = () => this.play();
#       document.getElementById('sleepBtn').onclick = () => this.sleep();
#       document.getElementById('logBtn').onclick = () => this.logToConsole();
#     }
#
#     // optional helper to print to console for debugging
#     logToConsole() {
#       console.log(`--- ${this.name} stats ---`);
#       console.log('Hunger:', this.hunger);
#       console.log('Energy:', this.energy);
#       console.log('Happiness:', this.happiness);
#       console.log('-----------------------');
#     }
#   }
#
#   // Create the pet and show initial status
#   // (You asked for "Anish" with high happiness/low hunger — set above)
#   if (!window._popcornPetInstance) {
#     window._popcornPetInstance = new Pet('Anish');
#   }
#   window._popcornPetInstance.status(`${window._popcornPetInstance.name} is ready! Click a button to interact.`);
# })();

# %% [markdown]
# ### <u>Homework</u>
#
# Complete the following questions in the next code block.
#
# 1) Create a class Person with properties 'name' and 'age'. Print their properties.
#
# 2) Add a method greet() to your Person class that prints a greeting using the person's name.
#
# 3) Create a class Book with properties 'title', 'author', and 'pages'. Instantiate a book and print its properties.
#
# 4) Add a method read(pages) to your Book class that increments a pagesRead property and prints a message.
#
# 5) Add a method isLongBook() that returns true if pages > 300, otherwise false. Print the result for your book.
#
# 6) Create a class Car with properties 'make', 'model', and 'fuel'. Add methods drive(distance) and refuel(amount). Print messages in each method.
#
# 7) Add a static method info() to your Car class that prints 'Cars are vehicles.'
#
# 8) Create a class ElectricCar that extends Car. Add a property 'battery' and a method charge(amount) that increases battery. Print battery level after charging.
#
# 10) Create a routine that combines your objects: drive a Car, charge an ElectricCar, read pages from a Book, and call greet() on Person. Print outputs for each action.
#
# 11) **Extra Credit:** Submit the original OOP Breakout Game Code (found on [OpenCS](https://github.com/Open-Coding-Society/pages/blob/main/hacks/breakout/breakout.md?plain=1)) after making the following edits:
# - Add another feature to the game: Add a method so that the ball must collide with some bricks twice for a brick to break completely.
# - Edit a method in the ball class to increase/decrease the speed of the ball: Please add a COMMENT on the game code that specifies which line you edited.

# %%
# %%javascript
# // ====================
# // HOMEWORK CLASSES
# // ====================
#
# // 1️⃣ Person Class
# class Person {
#   constructor(name, age) {
#     this.name = name;
#     this.age = age;
#   }
#
#   greet() {
#     console.log(`Hello! My name is ${this.name} and I am ${this.age} years old.`);
#   }
# }
#
# // Test Person
# let person1 = new Person("Alice", 25);
# console.log("👤 Person Class 👤");
# console.log(person1);
# person1.greet();
#
#
# // 2️⃣ Book Class
# class Book {
#   constructor(title, author, pages) {
#     this.title = title;
#     this.author = author;
#     this.pages = pages;
#     this.pagesRead = 0;
#   }
#
#   read(pages) {
#     this.pagesRead += pages;
#     if (this.pagesRead > this.pages) this.pagesRead = this.pages;
#     console.log(`You have read ${this.pagesRead} pages of "${this.title}".`);
#   }
#
#   isLongBook() {
#     return this.pages > 300;
#   }
# }
#
# // Test Book
# let book1 = new Book("JavaScript Basics", "John Doe", 350);
# console.log("📚 Book Class 📚");
# console.log(book1);
# book1.read(50);
# console.log("Is it a long book?", book1.isLongBook());
#
#
# // 3️⃣ Car Class
# class Car {
#   constructor(make, model, fuel) {
#     this.make = make;
#     this.model = model;
#     this.fuel = fuel;
#   }
#
#   drive(distance) {
#     const fuelUsed = distance * 0.1;
#     if (fuelUsed > this.fuel) {
#       console.log(`Not enough fuel to drive ${distance} km.`);
#       return;
#     }
#     this.fuel -= fuelUsed;
#     console.log(`${this.make} ${this.model} drove ${distance} km. Fuel left: ${this.fuel.toFixed(2)}L`);
#   }
#
#   refuel(amount) {
#     this.fuel += amount;
#     console.log(`${this.make} ${this.model} refueled ${amount}L. Total fuel: ${this.fuel.toFixed(2)}L`);
#   }
#
#   static info() {
#     console.log("Cars are vehicles.");
#   }
# }
#
# // Test Car
# let car1 = new Car("Toyota", "Corolla", 10);
# console.log("🚗 Car Class 🚗");
# car1.drive(50);
# car1.refuel(20);
# Car.info();
#
#
# // 4️⃣ ElectricCar Class
# class ElectricCar extends Car {
#   constructor(make, model, fuel, battery) {
#     super(make, model, fuel);
#     this.battery = battery;
#   }
#
#   charge(amount) {
#     this.battery += amount;
#     if (this.battery > 100) this.battery = 100;
#     console.log(`${this.make} ${this.model} charged. Battery: ${this.battery}%`);
#   }
# }
#
# // Test ElectricCar
# let eCar = new ElectricCar("Tesla", "Model 3", 0, 50);
# console.log("⚡ ElectricCar Class ⚡");
# eCar.charge(30);
# eCar.drive(30);
#
#
# // 5️⃣ Routine combining all objects
# console.log("🔄 Routine combining all objects 🔄");
#
# let person2 = new Person("Bob", 30);
# let book2 = new Book("Advanced JS", "Jane Smith", 200);
# let car2 = new Car("Honda", "Civic", 15);
# let eCar2 = new ElectricCar("Tesla", "Model X", 0, 20);
#
# person2.greet();
# book2.read(40);
# console.log("Is the book long?", book2.isLongBook());
# car2.drive(100);
# car2.refuel(10);
# eCar2.charge(50);
# eCar2.drive(30);
